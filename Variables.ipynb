# %%
print("hola mundo")
# Out:
# hola mundo

# %%
a=10+8
b=10
a+b*2
# Out:
# 38

# %%
import numpy as np

a=np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
saludo= "Hola mi nombre es"
nombre= "Santiago"
edad = 20
print(saludo,nombre +"!")
print("Tengo",edad,"años")
# Out:
# Hola mi nombre es Santiago!
# Tengo 20 años
