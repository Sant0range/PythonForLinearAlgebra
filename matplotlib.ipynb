# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(3,1,"ro")
plt.show()

# %%
x=np.arange(-9,10)
y=x**2
plt.plot(x,y,'r')
plt.plot(x,y/2,'gs')

# %%
plt.plot([0,3],[-1,1],label="Primera línea")
plt.plot([-2,0],[-4,1],label="Segunda línea")
plt.legend()
plt.show()

# %%
M=np.random.randint(0,10, size=(4,5))
M
# Out:
# array([[3, 1, 9, 5, 4],
#        [7, 5, 7, 6, 8],
#        [9, 2, 8, 3, 8],
#        [8, 7, 6, 5, 1]], dtype=int32)

# %%
M=np.random.randint(0,10, size=(4,5))
plt.imshow(M)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([0, M.shape[1] -1], [0, M.shape[0] - 1],label="primera línea",color="green", linewidth=2) 
plt.plot([0, M.shape[1] - 1], [M.shape[0] - 1, 0],label="Segunda línea", linewidth=2)
plt.legend()
plt.imshow(M)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
